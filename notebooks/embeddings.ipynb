# %%
# !pip install sentence-transformers chromadb -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.3/23.3 MB 50.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 16.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 63.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.7/18.7 MB 61.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.8/71.8 kB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.9/170.9 kB 9.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.3/61.3 kB 3.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.7/203.7 kB 10.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 4.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 4.3 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-adk 1.29.0 requires opentelemetry-api<1.39.0,>=1.36.0, but you have opentelemetry-api 1.42.1 which is incompatible.
# google-adk 1.29.0 requires opentelemetry-sdk<1.39.0,>=1.36.0, but you have opentelemetry-sdk 1.42.1 which is incompatible.
# opentelemetry-exporter-gcp-logging 1.11.0a0 requires opentelemetry-sdk<1.39.0,>=1.35.0, but you have opentelemetry-sdk 1.42.1 which is incompatible.
# opentelemetry-exporter-otlp-proto-http 1.38.0 requires opentelemetry-exporter-otlp-proto-common==1.38.0, but you have opentelemetry-exporter-otlp-proto-common 1.42.1 which is incompatible.
# opentelemetry-exporter-otlp-proto-http 1.38.0 requires opentelemetry-proto==1.38.0, but you have opentelemetry-proto 1.42.1 which is incompatible.
# opentelemetry-exporter-otlp-proto-http 1.38.0 requires opentelemetry-sdk~=1.38.0, but you have opentelemetry-sdk 1.42.1 which is incompatible.

# %%
from sentence_transformers import SentenceTransformer
import chromadb

print("Everything installed successfully!")
# Out:
# Everything installed successfully!

# %%
import pandas as pd

df = pd.read_csv("asrs_clean.csv")

print(df.shape)
df.head()
# Out:
# (19692, 7)
#        ACN    Date                           Primary Problem  \
# 0  2068164  202401                             Human Factors
# 1  2068412  202401                             Human Factors
# 2  2068417  202401  ATC Equipment / Nav Facility / Buildings
# 3  2068537  202401                             Human Factors
# 4  2068539  202401                                 Procedure
#
#                    Contributing Factors / Situations  \
# 0                           Procedure; Human Factors
# 1                           Human Factors; Procedure
# 2  ATC Equipment / Nav Facility / Buildings; Airc...
# 3                           Human Factors; Procedure
# 4  Chart Or Publication; Procedure; Airspace Stru...
#
#                                               Result  \
# 0  Flight Crew Rejected Takeoff; Flight Crew Took...
# 1                      General None Reported / Taken
# 2             Flight Crew Overcame Equipment Problem
# 3                    Flight Crew Took Evasive Action
# 4  Flight Crew Requested ATC Assistance / Clarifi...
#
#                                             Synopsis  \
# 0  DA-7X flight crew rejected a takeoff due to an...
# 1  Ground observer reported a critical ground con...
# 2  Air carrier pilot reported GPS spoofing at cru...
# 3  General aviation Instructor reported a near mi...
# 4  Experimental aircraft pilot operating in ZMA a...
#
#                                       full_narrative
# 0  Was told to line up and wait runway XXR at int...
# 1  A large corporate aircraft taxied with in 5-8 ...
# 2  GPS Spoofing. Enroute today from ZZZ to SOF; w...
# 3  Practicing simulated arcs with instrument stud...
# 4  I was enroute southeast bound on T208 VFR; in ...

# %%
print(df.isnull().sum())
# Out:
# ACN                                    0
# Date                                   0
# Primary Problem                       18
# Contributing Factors / Situations     13
# Result                               850
# Synopsis                               0
# full_narrative                         0
# dtype: int64

# %%
print(df["full_narrative"].duplicated().sum())
# Out:
# 3116

# %%
df["length"] = df["full_narrative"].str.len()

print(df["length"].describe())
# Out:
# count    19692.000000
# mean      1635.353951
# std       1519.987687
# min         52.000000
# 25%        682.000000
# 50%       1195.000000
# 75%       2047.250000
# max      21212.000000
# Name: length, dtype: float64

# %%
df = df.dropna(subset=["full_narrative"])

df = df[
    df["full_narrative"].str.len() > 100
]

df = df.drop_duplicates(
    subset=["full_narrative"]
)

print(df.shape)
# Out:
# (16502, 8)

# %%
df.to_csv(
    "asrs_clean_v2.csv",
    index=False
)

# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer(
    "BAAI/bge-small-en-v1.5"
)

print("Model Loaded")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:112: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config_sentence_transformers.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/94.8k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/743 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/133M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/366 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Model Loaded

# %%
documents = df[
    "full_narrative"
].tolist()

print(len(documents))
# Out:
# 16502

# %%
embeddings = model.encode(
    documents,
    show_progress_bar=True
)
# Out:
# Batches:   0%|          | 0/516 [00:00<?, ?it/s]

# %%
print(embeddings.shape)
# Out:
# (16502, 384)

# %%
import numpy as np

np.save(
    "asrs_embeddings.npy",
    embeddings
)

print("Embeddings saved!")
# Out:
# Embeddings saved!

# %%
df.to_csv(
    "asrs_clean_final.csv",
    index=False
)

# %%
from sklearn.metrics.pairwise import cosine_similarity

query = """
Aircraft taxiing in low visibility.
Communication delays reported.
"""

query_embedding = model.encode([query])

scores = cosine_similarity(
    query_embedding,
    embeddings
)[0]

top_indices = scores.argsort()[-5:][::-1]

# %%
for idx in top_indices:
    print("="*80)
    print(df.iloc[idx]["full_narrative"][:1000])
    print("\nScore:", scores[idx])
# Out:
# ================================================================================
# In the pattern for D56; we landed Runway 36 and taxi'd to the end of the runway to prepare for back taxi on Runway 18. As we turned around and prepared to make a radio call; another aircraft overflew us about 100 feet and then remained at a very low altitude while maneuvering around the field; waiting for us to back taxi. The aircraft was making no radio calls and we were unaware of its presence while we were in the pattern. Lack of radio communications by the aircraft; lack of position reporting equipment. Radio communications between all aircraft operating within the vicinity of an uncontrolled field.
#
# Score: 0.80632997
# ================================================================================
# During a particularly busy period at FLY; possibly due to increased traffic on Day 0; an aircraft without ADS-B made a short final approach to Runway 15 and was not visible until it was 50 ft. AGL. As the pilot of a taxiing aircraft; I immediately stopped upon spotting the aircraft on final approach. After the aircraft landed; I proceeded to taxi onto the runway and then exited via the taxiway to avoid disrupting the sequence of other aircraft preparing for landing. The airfield was notably congested; with more than four aircraft in the pattern. It was concerning that this near-collision incident seemed unnoticed by other pilots in the vicinity.
#
# Score: 0.80215985
# ================================================================================
# On taxi out from the gate; we were cleared to taxi to [Runway] 10L/DD via A13; B1; and N. As we entered A13; 3 vehicles approached B1 from the west on the service road. The first 2 vehicles crossed B1 as we turned briefly onto B. As we began our turn onto B1; the third vehicle; [a] Company passenger bus; slowed as if to stop to let us by; then suddenly accelerated and crossed B1 in front of us; forcing me to stop the aircraft to prevent a collision. We notified Ground of the incident. This is the third time in 2 weeks that a vehicle cut across a taxiway close in front of my aircraft while I was taxiing. The last incident also involved a bus and I reported that.Drivers need to be reminded that they need to yield to moving aircraft and possibly retrained if they fail to do so.
#
# Score: 0.7807097
# ================================================================================
# I was on the ground at ZZZ airport next to the grass strip where I observed a near Miss. One ultra light plane was taking off of XX and a second plane was in the pattern for XY on the right hand down wind. The second plane was a high wing Cessna.The plane on down wind seemed to be lower than pattern altitude. The ultra light seemed to level off abruptly when he saw the other plane. Being on the ground; I don't know what kind of communication took place.
#
# Score: 0.78041077
# ================================================================================
# During this event I was working Ground Control; Clearance Delivery and Flight DATA. I was informed by Ops that a vehicle had crossed Runway XXR from Taxiway 1 and Taxiway 2 heading eastbound and joined the vehicles staged at Taxiway 2. Vehicle returned crossing XXR again at the same intersection heading westbound; narrowly missing the landing of a [priority handling] Aircraft X on RWY XXR. It was reported by Ops that the driver of the vehicle had to 'slam their brakes' to avoid a collision with Aircraft X. At no point in time during the two XXR incursions was the vehicle in communication with ground control or the local controller when utilizing the taxiways or crossing XXR. Vehicle was not visible from the tower due to nighttime conditions and no vehicle flashing lights were observed.Time of events as observed in ASCC (Airport Surface Surveillance Capability) playback:XA:40:32z - Vehicle 2 + 3 cross Rwy XXR at Taxiway 2 intersectionXA:41:07z - Vehicle 2 + 3 are clear of RWY XXR on Tax
#
# Score: 0.7796848

# %%
# !ls -lh
# Out:
# total 123M
# -rw-r--r-- 1 root root  37M Jun 19 04:16 asrs_clean.csv
# -rw-r--r-- 1 root root  31M Jun 19 05:57 asrs_clean_final.csv
# -rw-r--r-- 1 root root  31M Jun 19 04:16 asrs_clean_v2.csv
# -rw-r--r-- 1 root root  25M Jun 19 05:57 asrs_embeddings.npy
# drwxr-xr-x 1 root root 4.0K Jun  4 13:32 sample_data

# %%
from google.colab import files

files.download("asrs_embeddings.npy")

# %%
files.download("asrs_clean_final.csv")

# %%
# !pip install chromadb -q

# %%
import chromadb

client = chromadb.Client()

collection = client.create_collection(
    name="aviation_incidents"
)

print("Collection Created")
# Out:
# Collection Created

# %%
documents = df["full_narrative"].tolist()

# %%
batch_size = 5000

for i in range(0, len(documents), batch_size):

    collection.add(
        ids=[str(j) for j in range(i, min(i + batch_size, len(documents)))],
        documents=documents[i:i + batch_size],
        embeddings=embeddings[i:i + batch_size].tolist()
    )

    print(f"Added batch {i//batch_size + 1}")

print("All documents stored successfully!")
# Out:
# Added batch 1
# Added batch 2
# Added batch 3
# Added batch 4
# All documents stored successfully!

# %%
import chromadb

client = chromadb.PersistentClient(
    path="./chroma_db"
)

collection = client.get_or_create_collection(
    name="aviation_incidents"
)

print("Persistent ChromaDB Created!")
# Out:
# Persistent ChromaDB Created!

# %%
batch_size = 5000

for i in range(0, len(documents), batch_size):

    collection.add(
        ids=[str(j) for j in range(i, min(i + batch_size, len(documents)))],
        documents=documents[i:i + batch_size],
        embeddings=embeddings[i:i + batch_size].tolist()
    )

    print(f"Added batch {i//batch_size + 1}")

print("Done!")
# Out:
# Added batch 1
# Added batch 2
# Added batch 3
# Added batch 4
# Done!

# %%
print(collection.count())
# Out:
# 16502

# %%
# !ls -R chroma_db
# Out:
# chroma_db:
# ca5646cf-d4c4-48e0-96f1-1722d597f7e0  chroma.sqlite3
#
# chroma_db/ca5646cf-d4c4-48e0-96f1-1722d597f7e0:
# data_level0.bin  header.bin  index_metadata.pickle  length.bin	link_lists.bin

# %%
import chromadb

new_client = chromadb.PersistentClient(
    path="./chroma_db"
)

new_collection = new_client.get_collection(
    "aviation_incidents"
)

print(new_collection.count())
# Out:
# 16502

# %%
# !zip -r chroma_db.zip chroma_db
# Out:
#   adding: chroma_db/ (stored 0%)
#   adding: chroma_db/chroma.sqlite3 (deflated 46%)
#   adding: chroma_db/ca5646cf-d4c4-48e0-96f1-1722d597f7e0/ (stored 0%)
#   adding: chroma_db/ca5646cf-d4c4-48e0-96f1-1722d597f7e0/length.bin (deflated 75%)
#   adding: chroma_db/ca5646cf-d4c4-48e0-96f1-1722d597f7e0/header.bin (deflated 56%)
#   adding: chroma_db/ca5646cf-d4c4-48e0-96f1-1722d597f7e0/index_metadata.pickle (deflated 62%)
#   adding: chroma_db/ca5646cf-d4c4-48e0-96f1-1722d597f7e0/data_level0.bin (deflated 11%)
#   adding: chroma_db/ca5646cf-d4c4-48e0-96f1-1722d597f7e0/link_lists.bin (deflated 80%)

# %%
from google.colab import files

files.download("chroma_db.zip")
